# %%
import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
gdf_petrol = gpd.read_file('petrol_stations.geojson')
gdf_ev = gpd.read_file('charging_stations.geojson')

# %%
print(gdf_petrol.head())
print(gdf_petrol.columns)

print(gdf_ev.head())
print(gdf_ev.columns)
# Out:
#                  id               @id   LPG access  addr addr2 addr3  \
# 0  relation/1379562  relation/1379562  None   None  None  None  None
# 1      node/2768092      node/2768092  None   None  None  None  None
# 2       way/4076660       way/4076660  None   None  None  None  None
# 3  relation/4267293  relation/4267293  None   None  None  None  None
# 4       way/4299877       way/4299877  None   None  None  None  None
#
#      addr:city addr:city:en addr:city:gd  ... waterway  \
# 0         None         None         None  ...     None
# 1  Northampton         None         None  ...     None
# 2         None         None         None  ...     None
# 3         None         None         None  ...     None
# 4         None         None         None  ...     None
#
#                                              website website1 wheelchair  \
# 0                                               None     None       None
# ...

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 8))
gdf_petrol.plot(ax=axes[0], marker ='o', markersize = 5, alpha = 0.6, c = 'blue', label = 'Petrol Stations')

axes[0].set_title('Petrol Stations in the UK (OSM Data)')
axes[0].set_axis_off()
axes[0].legend(loc='upper left')

gdf_ev.plot(ax=axes[1], marker ='o', markersize = 5, alpha = 0.6, c = 'skyblue', label = 'EV Charging Stations')

axes[1].set_title('EV Charging Stations in the UK (OSM Data)')
axes[1].set_axis_off()
axes[1].legend(loc='upper left')
plt.tight_layout()
plt.show()
